# %%
import os
import glob
import dill

# %%
# path = os.environ.get('PROJECT_PATH')

with open(glob.glob(f'~/airflow_hw/data/models/*.pkl')[0], 'rb') as file:
    pipe = dill.load(file)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 # path = os.environ.get('PROJECT_PATH')
# ----> 3 with open(glob.glob(f'~/airflow_hw/data/models/*.pkl')[0], 'rb') as file:
#       4     pipe = dill.load(file)
#
# IndexError: list index out of range
